# %% [markdown]
# ## Medical Case :- Mental Health and Technology Usage Data Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('mental_health_and_technology_usage_2024.csv')

# %%
data
# Out:
#          User_ID  Age  Gender  Technology_Usage_Hours  \
# 0     USER-00001   23  Female                    6.57
# 1     USER-00002   21    Male                    3.01
# 2     USER-00003   51    Male                    3.04
# 3     USER-00004   25  Female                    3.84
# 4     USER-00005   53    Male                    1.20
# ...          ...  ...     ...                     ...
# 9995  USER-09996   42    Male                    7.05
# 9996  USER-09997   31   Other                    3.12
# 9997  USER-09998   23    Male                    4.38
# 9998  USER-09999   38    Male                    4.44
# 9999  USER-10000   41    Male                    2.50
#
#       Social_Media_Usage_Hours  Gaming_Hours  Screen_Time_Hours  \
# 0                         6.00          0.68              12.36
# 1                         2.57          3.74               7.61
# 2                         6.14          1.26               3.16
# ...

# %%
data.drop('User_ID',axis=1,inplace=True)    ## This columns is not import for my data

# %% [markdown]
# ## Basic Check

# %%
data.shape
# Out:
# (10000, 13)

# %%
data.head()
# Out:
#    Age  Gender  Technology_Usage_Hours  Social_Media_Usage_Hours  \
# 0   23  Female                    6.57                      6.00
# 1   21    Male                    3.01                      2.57
# 2   51    Male                    3.04                      6.14
# 3   25  Female                    3.84                      4.48
# 4   53    Male                    1.20                      0.56
#
#    Gaming_Hours  Screen_Time_Hours Mental_Health_Status Stress_Level  \
# 0          0.68              12.36                 Good          Low
# 1          3.74               7.61                 Poor         High
# 2          1.26               3.16                 Fair         High
# 3          2.59              13.08            Excellent       Medium
# 4          0.29              12.63                 Good          Low
#
#    Sleep_Hours  Physical_Activity_Hours Support_Systems_Access  \
# 0         8.01                     6.71                     No
# ...

# %%
data.tail()
# Out:
#       Age Gender  Technology_Usage_Hours  Social_Media_Usage_Hours  \
# 9995   42   Male                    7.05                      0.41
# 9996   31  Other                    3.12                      6.79
# 9997   23   Male                    4.38                      3.98
# 9998   38   Male                    4.44                      1.48
# 9999   41   Male                    2.50                      4.80
#
#       Gaming_Hours  Screen_Time_Hours Mental_Health_Status Stress_Level  \
# 9995          0.53              13.90                 Good       Medium
# 9996          0.80               1.17                 Fair       Medium
# 9997          0.52               7.81                 Poor         High
# 9998          3.28              13.95                 Poor       Medium
# 9999          0.25               8.82                 Fair          Low
#
#       Sleep_Hours  Physical_Activity_Hours Support_Systems_Access  \
# ...

# %%
data.sample(5)
# Out:
#       Age  Gender  Technology_Usage_Hours  Social_Media_Usage_Hours  \
# 5035   55   Other                    2.26                      4.57
# 6307   48  Female                    5.72                      7.76
# 583    51    Male                    6.38                      6.28
# 7718   36    Male                    2.80                      4.00
# 9553   18  Female                    4.40                      4.83
#
#       Gaming_Hours  Screen_Time_Hours Mental_Health_Status Stress_Level  \
# 5035          1.38              11.63                 Good         High
# 6307          2.29               7.43                 Fair         High
# 583           3.13              14.78                 Good          Low
# 7718          2.00              14.33                 Good         High
# 9553          4.08               7.46                 Poor          Low
#
#       Sleep_Hours  Physical_Activity_Hours Support_Systems_Access  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       10000 non-null  int64
#  1   Gender                    10000 non-null  object
#  2   Technology_Usage_Hours    10000 non-null  float64
#  3   Social_Media_Usage_Hours  10000 non-null  float64
#  4   Gaming_Hours              10000 non-null  float64
#  5   Screen_Time_Hours         10000 non-null  float64
#  6   Mental_Health_Status      10000 non-null  object
#  7   Stress_Level              10000 non-null  object
#  8   Sleep_Hours               10000 non-null  float64
#  9   Physical_Activity_Hours   10000 non-null  float64
#  10  Support_Systems_Access    10000 non-null  object
#  11  Work_Environment_Impact   10000 non-null  object
#  12  Online_Support_Usage      10000 non-null  object
# dtypes: float64(6), int64(1), object(6)
# ...

# %%
data.describe()
# Out:
#                 Age  Technology_Usage_Hours  Social_Media_Usage_Hours  \
# count  10000.000000            10000.000000              10000.000000
# mean      41.518600                6.474341                  3.972321
# std       13.920217                3.169022                  2.313707
# min       18.000000                1.000000                  0.000000
# 25%       29.000000                3.760000                  1.980000
# 50%       42.000000                6.425000                  3.950000
# 75%       54.000000                9.212500                  5.990000
# max       65.000000               12.000000                  8.000000
#
#        Gaming_Hours  Screen_Time_Hours   Sleep_Hours  Physical_Activity_Hours
# count  10000.000000       10000.000000  10000.000000             10000.000000
# mean       2.515598           7.975765      6.500724                 5.003860
# std        1.446748           4.042608      1.450933                 2.905044
# ...

# %%
data.describe(include='O')
# Out:
#        Gender Mental_Health_Status Stress_Level Support_Systems_Access  \
# count   10000                10000        10000                  10000
# unique      3                    4            3                      2
# top     Other            Excellent       Medium                     No
# freq     3364                 2518         3338                   5006
#
#        Work_Environment_Impact Online_Support_Usage
# count                    10000                10000
# unique                       3                    2
# top                   Negative                   No
# freq                      3378                 5013

# %%
data.isnull().sum()  ## There is no Missing Values
# Out:
# Age                         0
# Gender                      0
# Technology_Usage_Hours      0
# Social_Media_Usage_Hours    0
# Gaming_Hours                0
# Screen_Time_Hours           0
# Mental_Health_Status        0
# Stress_Level                0
# Sleep_Hours                 0
# Physical_Activity_Hours     0
# Support_Systems_Access      0
# Work_Environment_Impact     0
# Online_Support_Usage        0
# dtype: int64

# %%
data.duplicated().sum()   ## There is No duplicated Values
# Out:
# 0

# %%
data.nunique()  ## Check Num of unique values in per column
# Out:
# Age                           48
# Gender                         3
# Technology_Usage_Hours      1101
# Social_Media_Usage_Hours     801
# Gaming_Hours                 501
# Screen_Time_Hours           1400
# Mental_Health_Status           4
# Stress_Level                   3
# Sleep_Hours                  501
# Physical_Activity_Hours     1001
# Support_Systems_Access         2
# Work_Environment_Impact        3
# Online_Support_Usage           2
# dtype: int64

# %%
data.dtypes
# Out:
# Age                           int64
# Gender                       object
# Technology_Usage_Hours      float64
# Social_Media_Usage_Hours    float64
# Gaming_Hours                float64
# Screen_Time_Hours           float64
# Mental_Health_Status         object
# Stress_Level                 object
# Sleep_Hours                 float64
# Physical_Activity_Hours     float64
# Support_Systems_Access       object
# Work_Environment_Impact      object
# Online_Support_Usage         object
# dtype: object

# %%
cat_col = data.select_dtypes(include='O')
cat_col.columns
# Out:
# Index(['Gender', 'Mental_Health_Status', 'Stress_Level',
#        'Support_Systems_Access', 'Work_Environment_Impact',
#        'Online_Support_Usage'],
#       dtype='object')

# %%
num_col = data.select_dtypes(include=['int','float'])
num_col.columns
# Out:
# Index(['Age', 'Technology_Usage_Hours', 'Social_Media_Usage_Hours',
#        'Gaming_Hours', 'Screen_Time_Hours', 'Sleep_Hours',
#        'Physical_Activity_Hours'],
#       dtype='object')

# %%
for i in cat_col:
    print(i,cat_col[i].unique())
    print(cat_col[i].value_counts())
    print('************************************************************')
# Out:
# Gender ['Female' 'Male' 'Other']
# Gender
# Other     3364
# Male      3350
# Female    3286
# Name: count, dtype: int64
# ************************************************************
# Mental_Health_Status ['Good' 'Poor' 'Fair' 'Excellent']
# Mental_Health_Status
# Excellent    2518
# Good         2508
# Fair         2490
# Poor         2484
# Name: count, dtype: int64
# ************************************************************
# Stress_Level ['Low' 'High' 'Medium']
# Stress_Level
# Medium    3338
# Low       3332
# High      3330
# Name: count, dtype: int64
# ************************************************************
# Support_Systems_Access ['No' 'Yes']
# Support_Systems_Access
# No     5006
# Yes    4994
# Name: count, dtype: int64
# ************************************************************
# Work_Environment_Impact ['Negative' 'Positive' 'Neutral']
# Work_Environment_Impact
# Negative    3378
# Neutral     3312
# Positive    3310
# Name: count, dtype: int64
# ...

# %%
data.sort_values('Age')
# Out:
#       Age  Gender  Technology_Usage_Hours  Social_Media_Usage_Hours  \
# 3550   18    Male                    5.45                      5.99
# 173    18  Female                   10.93                      6.34
# 2824   18  Female                   10.82                      1.79
# 8776   18   Other                    7.81                      6.81
# 8774   18  Female                    8.85                      3.54
# ...   ...     ...                     ...                       ...
# 2657   65   Other                    3.26                      2.18
# 5776   65    Male                    4.19                      2.10
# 3026   65  Female                    6.96                      3.60
# 4624   65   Other                    8.46                      7.64
# 7974   65  Female                    4.69                      0.27
#
#       Gaming_Hours  Screen_Time_Hours Mental_Health_Status Stress_Level  \
# 3550          1.85              11.79            Excellent       Medium
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ## Univarint analysis

# %%
data.Mental_Health_Status.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
data.Stress_Level.value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(x='Stress_Level',data=data,hue='Gender')
plt.title('Stress Level in Gender')
# Out:
# Text(0.5, 1.0, 'Stress Level in Gender')

# %%
# Count plot for Work Environment Impact by Mental Health Status
plt.figure(figsize=(8,5))
sns.countplot(x='Work_Environment_Impact', hue='Mental_Health_Status', data=data, palette='Set2')
plt.title('Work Environment Impact by Mental Health Status')
plt.xlabel('Work Environment Impact')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(25,20))
plotnumber=1
for i in cat_col:
    if plotnumber<=7:
        plt.subplot(4,3,plotnumber)
        sns.countplot(x=cat_col[i],hue='Mental_Health_Status',data=cat_col)
        plt.xlabel(i,fontsize=15)
        plt.ylabel('Count',fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %%
plt.figure(figsize=(16,12))
plotnumber=1
for i in num_col:
    if plotnumber<=7:
        plt.subplot(4,3,plotnumber)
        sns.histplot(num_col[i],kde=True)
        plt.xlabel(i,fontsize=15)
        plt.ylabel('Count',fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# ## Bivariate Analysis

# %%
## Scatter Plot for Age vs Screen Time Hours
plt.figure(figsize=(8,5))
sns.scatterplot(x='Age', y='Screen_Time_Hours', data=data, hue='Gender')
plt.title('Age vs Screen Time Hours')
plt.xlabel('Age')
plt.ylabel('Screen Time (Hours)')
plt.show()

# %%
## line Plot for Screen 

plt.figure(figsize=(8,5))
plt.plot(data['Screen_Time_Hours'], label = ['Sreen Time Hours'],color='blue')
plt.plot(data['Gaming_Hours'], label = ['Gaming Hours'], color = 'red')
plt.xlabel('Index')
plt.ylabel('Hours')
plt.title('Screen Time Hours vs Gaming Hours')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x='Sleep_Hours', y='Technology_Usage_Hours', data=data, hue='Mental_Health_Status', palette='Set1')
plt.title('Sleep Hours vs Technology Usage Hours')
plt.xlabel('Sleep Hours')
plt.ylabel('Technology Usage Hours')
plt.show()

# %%
# Scatter plot for Technology Usage Hours vs Screen Time Hours
plt.figure(figsize=(8,5))
sns.scatterplot(x='Technology_Usage_Hours', y='Screen_Time_Hours', data=data, hue='Mental_Health_Status', palette='Set2')
plt.title('Technology Usage Hours vs Screen Time Hours')
plt.xlabel('Technology Usage Hours')
plt.ylabel('Screen Time Hours')
plt.show()

# %%
import sweetviz as sv
my_report = sv.analyze(data)
my_report.show_html()
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
plt.figure(figsize=(8,5))
sns.lineplot(x='Screen_Time_Hours', y='Mental_Health_Status', data=data)
plt.title('Screen Time Hours vs Mental Health Status')
plt.xlabel('Screen Time Hours')
plt.ylabel('Mental Health Status')
plt.show()

# %%
Summary = pd.DataFrame()
Summary['Columns'] = ['Total Users','Average Age','Average Technology Usage Hours','Average Social Media Usage Hours','Average Gaming Hours',
                   'Average Screen Time Hours','Average Stress Level','Average Sleep Hours','Average Physical Activity Hours']
Summary['Values'] = ['10000','41.5 years','6.5 hours','4.3 hours','2.5 hours','8.3 hours','6.5 hours','7.3 hours','1.2 hours']

# %% [markdown]
# ## Average

# %%
Summary
# Out:
#                             Columns      Values
# 0                       Total Users       10000
# 1                       Average Age  41.5 years
# 2    Average Technology Usage Hours   6.5 hours
# 3  Average Social Media Usage Hours   4.3 hours
# 4              Average Gaming Hours   2.5 hours
# 5         Average Screen Time Hours   8.3 hours
# 6              Average Stress Level   6.5 hours
# 7               Average Sleep Hours   7.3 hours
# 8   Average Physical Activity Hours   1.2 hours

# %% [markdown]
# ## Insights

# %% [markdown]
# **Age:** The distribution of ages appears to be relatively uniform, with a slight increase in frequency around the ages of 20-30 and 40-50. This suggests that the sample includes people from a fairly diverse age range.
#
# **Technology Usage Hours:**
# - The histogram for technology usage hours is skewed to the right, indicating that a majority of people spend a moderate amount of time on technology, with a smaller group spending significantly more time.
#
# **Social Media Usage Hours:**
# - Similar to technology usage hours, the distribution of social media usage hours is skewed to the right, suggesting that a majority of people use social media for a moderate amount of time, while a smaller group spends significantly more time.
#
# **Gaming Hours:**
# - The histogram for gaming hours is also skewed to the right, with a peak around 2-3 hours per day. This indicates that a majority of people spend a moderate amount of time gaming, while a smaller group spends significantly more time.
#
# **Screen Time Hours:**
# - The distribution of screen time hours is skewed to the right, similar to the other variables related to technology usage. This suggests that a majority of people spend a moderate amount of time in front of screens, while a smaller group spends significantly more time.
#
# **Sleep Hours:**
# - The histogram for sleep hours appears to be relatively normal, with a peak around 7-8 hours per day. This indicates that most people get a good amount of sleep, with a smaller group getting either significantly less or more sleep.
#
# **Physical Activity Hours:**
# - The histogram for physical activity hours is skewed to the left, indicating that a majority of people engage in a moderate amount of physical activity, with a smaller group engaging in significantly less activity.
#
# **Gender:**
# - There are no significant differences in mental health status between genders.
#
# **Mental Health Status:**
# - The most common mental health status is "Good," followed by "Mild," "Moderate," and "Severe."
# - There are no significant differences in mental health status between different age groups.
#
# **Stress Level:**
# - Individuals with "High" stress levels are more likely to report "Severe" or "Moderate" mental health status compared to those with "Low" or "Medium" stress levels.
#
# **Support Systems Access:**
# - Individuals with "No" access to support systems are more likely to report "Severe" or "Moderate" mental health status compared to those with "Yes" or "Maybe" access.
#
# **Work Environment Impact:**
# - Individuals who report a "Negative" work environment impact are more likely to report "Severe" or "Moderate" mental health status compared to those who report a "Positive" or "Neutral" impact.
#
# **Online Support Usage:**
# - There are no significant differences in mental health status based on online support usage.
#
# Overall, the data suggests that stress levels, access to support systems, and work environment impact are associated with mental health status. Individuals who experience high stress levels, lack access to support systems, or report a negative work environment impact are more likely to report poorer mentaTtcomes.
#
#
# Overall, the data suggests that the group of people sampled is relatively diverse in terms of age and daily habits. However, there is a general tendency towards moderate levels of technology usage, social media usage, gaming, and screen time, with a smaller group engaging in these activities to a much greater extent. Additionally, most people get a good amount of sleep, while a smaller group engages in a moderate amount of physical activity.

# %% [markdown]
# ## Check Outliers

# %%
plt.figure(figsize=(16,12))
plotnumber=1
for i in num_col:
    if plotnumber<=7:
        plt.subplot(4,3,plotnumber)
        sns.boxplot(num_col[i])
        plt.xlabel(i,fontsize=15)
        plt.ylabel('Count',fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# There is No Outliers in this Dataset

# %%
for i in num_col:
    print(i,'Skew',num_col[i].skew())
    print('Min',num_col[i].min())
    print('Max',num_col[i].max())
    print('Mean',num_col[i].mean())
    print('Std',num_col[i].std())
    print('________________________________________________')
# Out:
# Age Skew 0.005154419002711
# Min 18
# Max 65
# Mean 41.5186
# Std 13.920216639231183
# ________________________________________________
# Technology_Usage_Hours Skew 0.01804686639334857
# Min 1.0
# Max 12.0
# Mean 6.474341
# Std 3.169022410148379
# ________________________________________________
# Social_Media_Usage_Hours Skew 0.010760400488291404
# Min 0.0
# Max 8.0
# Mean 3.972321
# Std 2.31370664233858
# ________________________________________________
# Gaming_Hours Skew -0.02354039565159173
# Min 0.0
# Max 5.0
# Mean 2.515598
# Std 1.4467484959442913
# ________________________________________________
# Screen_Time_Hours Skew 0.015483690433629712
# Min 1.0
# Max 15.0
# Mean 7.975764999999999
# Std 4.042607737897336
# ________________________________________________
# Sleep_Hours Skew 0.004032526163246173
# Min 4.0
# Max 9.0
# Mean 6.500723999999999
# Std 1.450933133028419
# ________________________________________________
# Physical_Activity_Hours Skew 0.0006123391409085536
# ...

# %% [markdown]
# ## Encoding Using Map

# %%
data.head()
# Out:
#    Age  Gender  Technology_Usage_Hours  Social_Media_Usage_Hours  \
# 0   23  Female                    6.57                      6.00
# 1   21    Male                    3.01                      2.57
# 2   51    Male                    3.04                      6.14
# 3   25  Female                    3.84                      4.48
# 4   53    Male                    1.20                      0.56
#
#    Gaming_Hours  Screen_Time_Hours Mental_Health_Status Stress_Level  \
# 0          0.68              12.36                 Good          Low
# 1          3.74               7.61                 Poor         High
# 2          1.26               3.16                 Fair         High
# 3          2.59              13.08            Excellent       Medium
# 4          0.29              12.63                 Good          Low
#
#    Sleep_Hours  Physical_Activity_Hours Support_Systems_Access  \
# 0         8.01                     6.71                     No
# ...

# %%
cat_col.columns
# Out:
# Index(['Gender', 'Mental_Health_Status', 'Stress_Level',
#        'Support_Systems_Access', 'Work_Environment_Impact',
#        'Online_Support_Usage'],
#       dtype='object')

# %%
## Gender
data.Gender.value_counts()
# Out:
# Gender
# Other     3364
# Male      3350
# Female    3286
# Name: count, dtype: int64

# %%
data.Gender=data.Gender.map({'Other':2,'Male':1,'Female':0})

# %%
data.head()
# Out:
#    Age  Gender  Technology_Usage_Hours  Social_Media_Usage_Hours  \
# 0   23       0                    6.57                      6.00
# 1   21       1                    3.01                      2.57
# 2   51       1                    3.04                      6.14
# 3   25       0                    3.84                      4.48
# 4   53       1                    1.20                      0.56
#
#    Gaming_Hours  Screen_Time_Hours  Mental_Health_Status  Stress_Level  \
# 0          0.68              12.36                     2             1
# 1          3.74               7.61                     0             0
# 2          1.26               3.16                     1             0
# 3          2.59              13.08                     3             2
# 4          0.29              12.63                     2             1
#
#    Sleep_Hours  Physical_Activity_Hours  Support_Systems_Access  \
# 0         8.01                     6.71                       1
# ...

# %%
## Mental_Health_Status
data.Mental_Health_Status.value_counts()
# Out:
# Mental_Health_Status
# Excellent    2518
# Good         2508
# Fair         2490
# Poor         2484
# Name: count, dtype: int64

# %%
data.Mental_Health_Status=data.Mental_Health_Status.map({'Excellent':3,'Good':2,'Fair':1,'Poor':0})
data.head()
# Out:
#    Age  Gender  Technology_Usage_Hours  Social_Media_Usage_Hours  \
# 0   23       0                    6.57                      6.00
# 1   21       1                    3.01                      2.57
# 2   51       1                    3.04                      6.14
# 3   25       0                    3.84                      4.48
# 4   53       1                    1.20                      0.56
#
#    Gaming_Hours  Screen_Time_Hours  Mental_Health_Status Stress_Level  \
# 0          0.68              12.36                     2          Low
# 1          3.74               7.61                     0         High
# 2          1.26               3.16                     1         High
# 3          2.59              13.08                     3       Medium
# 4          0.29              12.63                     2          Low
#
#    Sleep_Hours  Physical_Activity_Hours Support_Systems_Access  \
# 0         8.01                     6.71                     No
# ...

# %%
# Stress_Level
data.Stress_Level.value_counts()
# Out:
# Stress_Level
# Medium    3338
# Low       3332
# High      3330
# Name: count, dtype: int64

# %%
data.Stress_Level=data.Stress_Level.map({'Medium':2,'Low':1,'High':0})
data.head()
# Out:
#    Age  Gender  Technology_Usage_Hours  Social_Media_Usage_Hours  \
# 0   23       0                    6.57                      6.00
# 1   21       1                    3.01                      2.57
# 2   51       1                    3.04                      6.14
# 3   25       0                    3.84                      4.48
# 4   53       1                    1.20                      0.56
#
#    Gaming_Hours  Screen_Time_Hours  Mental_Health_Status  Stress_Level  \
# 0          0.68              12.36                     2             1
# 1          3.74               7.61                     0             0
# 2          1.26               3.16                     1             0
# 3          2.59              13.08                     3             2
# 4          0.29              12.63                     2             1
#
#    Sleep_Hours  Physical_Activity_Hours Support_Systems_Access  \
# 0         8.01                     6.71                     No
# ...

# %%
## Support_Systems_Access
data.Support_Systems_Access.value_counts()
# Out:
# Support_Systems_Access
# No     5006
# Yes    4994
# Name: count, dtype: int64

# %%
data.Support_Systems_Access=data.Support_Systems_Access.map({'No':1,'Yes':0})
data.head()
# Out:
#    Age  Gender  Technology_Usage_Hours  Social_Media_Usage_Hours  \
# 0   23       0                    6.57                      6.00
# 1   21       1                    3.01                      2.57
# 2   51       1                    3.04                      6.14
# 3   25       0                    3.84                      4.48
# 4   53       1                    1.20                      0.56
#
#    Gaming_Hours  Screen_Time_Hours  Mental_Health_Status  Stress_Level  \
# 0          0.68              12.36                     2             1
# 1          3.74               7.61                     0             0
# 2          1.26               3.16                     1             0
# 3          2.59              13.08                     3             2
# 4          0.29              12.63                     2             1
#
#    Sleep_Hours  Physical_Activity_Hours  Support_Systems_Access  \
# 0         8.01                     6.71                       1
# ...

# %%
## Work_Environment_Impact
data.Work_Environment_Impact.value_counts()
# Out:
# Work_Environment_Impact
# Negative    3378
# Neutral     3312
# Positive    3310
# Name: count, dtype: int64

# %%
data.Work_Environment_Impact=data.Work_Environment_Impact.map({'Negative':2,'Neutral':1,'Positive':0})
data.head()
# Out:
#    Age  Gender  Technology_Usage_Hours  Social_Media_Usage_Hours  \
# 0   23       0                    6.57                      6.00
# 1   21       1                    3.01                      2.57
# 2   51       1                    3.04                      6.14
# 3   25       0                    3.84                      4.48
# 4   53       1                    1.20                      0.56
#
#    Gaming_Hours  Screen_Time_Hours  Mental_Health_Status  Stress_Level  \
# 0          0.68              12.36                     2             1
# 1          3.74               7.61                     0             0
# 2          1.26               3.16                     1             0
# 3          2.59              13.08                     3             2
# 4          0.29              12.63                     2             1
#
#    Sleep_Hours  Physical_Activity_Hours  Support_Systems_Access  \
# 0         8.01                     6.71                       1
# ...

# %%
# Online_Support_Usage
data.Online_Support_Usage.value_counts()
# Out:
# Online_Support_Usage
# No     5013
# Yes    4987
# Name: count, dtype: int64

# %%
data.Online_Support_Usage=data.Online_Support_Usage.map({'No':1,'Yes':0})
data.head()
# Out:
#    Age  Gender  Technology_Usage_Hours  Social_Media_Usage_Hours  \
# 0   23       0                    6.57                      6.00
# 1   21       1                    3.01                      2.57
# 2   51       1                    3.04                      6.14
# 3   25       0                    3.84                      4.48
# 4   53       1                    1.20                      0.56
#
#    Gaming_Hours  Screen_Time_Hours  Mental_Health_Status  Stress_Level  \
# 0          0.68              12.36                     2             1
# 1          3.74               7.61                     0             0
# 2          1.26               3.16                     1             0
# 3          2.59              13.08                     3             2
# 4          0.29              12.63                     2             1
#
#    Sleep_Hours  Physical_Activity_Hours  Support_Systems_Access  \
# 0         8.01                     6.71                       1
# ...

# %%
data.isnull().sum()
# Out:
# Age                         0
# Gender                      0
# Technology_Usage_Hours      0
# Social_Media_Usage_Hours    0
# Gaming_Hours                0
# Screen_Time_Hours           0
# Mental_Health_Status        0
# Stress_Level                0
# Sleep_Hours                 0
# Physical_Activity_Hours     0
# Support_Systems_Access      0
# Work_Environment_Impact     0
# Online_Support_Usage        0
# dtype: int64

# %% [markdown]
# ## Check the Corr-relation

# %%
plt.figure(figsize=(16,8))
sns.heatmap(data.corr(),annot=True,cmap='rainbow',linewidth=0.5)
# Out:
# <Axes: >

# %% [markdown]
# ## Data Preprocessing

# %%
data1=data.copy()

# %%
## Scale the data
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
data1[['Age', 'Gender', 'Technology_Usage_Hours', 'Social_Media_Usage_Hours',
       'Gaming_Hours', 'Screen_Time_Hours',
       'Stress_Level', 'Sleep_Hours', 'Physical_Activity_Hours',
       'Support_Systems_Access', 'Work_Environment_Impact',
       'Online_Support_Usage']] = scale.fit_transform(data1[['Age', 'Gender', 'Technology_Usage_Hours', 'Social_Media_Usage_Hours',
       'Gaming_Hours', 'Screen_Time_Hours',
       'Stress_Level', 'Sleep_Hours', 'Physical_Activity_Hours',
       'Support_Systems_Access', 'Work_Environment_Impact',
       'Online_Support_Usage']])

# %%
data1.head()
# Out:
#         Age    Gender  Technology_Usage_Hours  Social_Media_Usage_Hours  \
# 0 -1.330405 -1.235900                0.030187                  0.876421
# 1 -1.474088 -0.009565               -1.093244                 -0.606123
# 2  0.681159 -0.009565               -1.083777                  0.936933
# 3 -1.186722 -1.235900               -0.831320                  0.219433
# 4  0.824842 -0.009565               -1.664426                 -1.474902
#
#    Gaming_Hours  Screen_Time_Hours  Mental_Health_Status  Stress_Level  \
# 0     -1.268838           1.084561                     2     -0.000980
# 1      0.846355          -0.090482                     0     -1.225603
# 2     -0.867919          -1.191312                     1     -1.225603
# 3      0.051430           1.262673                     3      1.223643
# 4     -1.538422           1.151353                     2     -0.000980
#
#    Sleep_Hours  Physical_Activity_Hours  Support_Systems_Access  \
# ...

# %% [markdown]
# ## Create X and y

# %%
X = data1.drop('Mental_Health_Status',axis=1)
y = data1.Mental_Health_Status

# %%
X.head(3)
# Out:
#         Age    Gender  Technology_Usage_Hours  Social_Media_Usage_Hours  \
# 0 -1.330405 -1.235900                0.030187                  0.876421
# 1 -1.474088 -0.009565               -1.093244                 -0.606123
# 2  0.681159 -0.009565               -1.083777                  0.936933
#
#    Gaming_Hours  Screen_Time_Hours  Stress_Level  Sleep_Hours  \
# 0     -1.268838           1.084561     -0.000980     1.040263
# 1      0.846355          -0.090482     -1.225603     0.537113
# 2     -0.867919          -1.191312     -1.225603     1.060940
#
#    Physical_Activity_Hours  Support_Systems_Access  Work_Environment_Impact  \
# 0                 0.587332                0.998801                 1.214517
# 1                 0.301608               -1.001201                -1.231148
# 2                 1.654495                0.998801                 1.214517
#
#    Online_Support_Usage
# 0             -1.002603
# 1              0.997403
# 2              0.997403

# %%
y.head(3)
# Out:
# 0    2
# 1    0
# 2    1
# Name: Mental_Health_Status, dtype: int64

# %%
## split the data
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,
                                                 random_state=18)

# %%
X_train.shape
# Out:
# (8000, 12)

# %%
y_test.shape
# Out:
# (2000,)

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter

# %%
smote = SMOTE()
X_smote,y_smote = smote.fit_resample(X_train,y_train)

# %%
print('Actual value',Counter(y_train))
print('SMOTE value',Counter(y_smote))
# Out:
# Actual value Counter({3: 2019, 2: 2017, 1: 1997, 0: 1967})
# SMOTE value Counter({2: 2019, 3: 2019, 0: 2019, 1: 2019})

# %% [markdown]
# # Create Models

# %% [markdown]
# ## Model 1: Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_smote,y_smote)
dt_pred = dt.predict(X_test)

# %%
## Check Metrics 
from sklearn.metrics import accuracy_score,classification_report
print(accuracy_score(y_test,dt_pred))
# Out:
# 0.846

# %%
print(classification_report(y_test,dt_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.84      0.84       491
#            1       0.84      0.84      0.84       537
#            2       0.84      0.87      0.86       490
#            3       0.85      0.84      0.85       482
#
#     accuracy                           0.85      2000
#    macro avg       0.85      0.85      0.85      2000
# weighted avg       0.85      0.85      0.85      2000

# %% [markdown]
# ## Model 2: Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_smote,y_smote)
rf_pred = rf.predict(X_test)

# %%
accuracy_score(y_test,rf_pred)
# Out:
# 0.8545

# %%
print(classification_report(y_test,rf_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.84      0.83       491
#            1       0.88      0.85      0.87       537
#            2       0.85      0.86      0.86       490
#            3       0.86      0.86      0.86       482
#
#     accuracy                           0.85      2000
#    macro avg       0.85      0.85      0.85      2000
# weighted avg       0.85      0.85      0.85      2000

# %%
pd.crosstab(y_test,rf_pred)
# Out:
# col_0                   0    1    2    3
# Mental_Health_Status
# 0                     412   26   33   20
# 1                      27  459   24   27
# 2                      32   16  423   19
# 3                      27   21   19  415

# %% [markdown]
# ## Model 3: Random Forest Classifier with RandomizedSearchCV

# %%
from sklearn.model_selection import RandomizedSearchCV

params = {
    'n_estimators':[50,100,150,200,250,300],
    'max_depth':(list(range(1,20))),
    'max_features':['auto','sqrt','log2'],
    'min_samples_split':[2,3,4],
    'min_samples_leaf':(list(range(1,20))),
    'bootstrap':[True,False]
}

rf2 = RandomForestClassifier()
rf_cv = RandomizedSearchCV(estimator=rf2, param_distributions=params, cv = 3, verbose = 2, scoring='accuracy', n_jobs=-1, n_iter=100)

rf_cv.fit(X_smote,y_smote)
best_param = rf_cv.best_params_
print(f'Best Parameters:{best_param}')
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Best Parameters:{'n_estimators': 150, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 18, 'bootstrap': False}

# %%
rf2 = RandomForestClassifier(n_estimators=100,min_samples_split=2,min_samples_leaf=3,max_features='sqrt',max_depth=21,bootstrap=False)
rf2.fit(X_smote,y_smote)
rf2_pred = rf2.predict(X_test)

# %%
accuracy_score(y_test,rf2_pred)
# Out:
# 0.8535

# %%
print(classification_report(y_test,rf2_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.85       491
#            1       0.87      0.86      0.87       537
#            2       0.83      0.86      0.84       490
#            3       0.85      0.86      0.85       482
#
#     accuracy                           0.85      2000
#    macro avg       0.85      0.85      0.85      2000
# weighted avg       0.85      0.85      0.85      2000

# %% [markdown]
# ## Model 4:- XGB Boost

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier(n_estimators=300)
xgb.fit(X_smote,y_smote)
xgb_pred = xgb.predict(X_test)

# %%
accuracy_score(y_test,xgb_pred)
# Out:
# 0.842

# %%
print(classification_report(y_test,xgb_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.84      0.84       491
#            1       0.85      0.83      0.84       537
#            2       0.83      0.84      0.84       490
#            3       0.84      0.86      0.85       482
#
#     accuracy                           0.84      2000
#    macro avg       0.84      0.84      0.84      2000
# weighted avg       0.84      0.84      0.84      2000

# %%
pd.crosstab(y_test,xgb_pred)
# Out:
# col_0                   0    1    2    3
# Mental_Health_Status
# 0                     409   30   33   19
# 1                      24  459   26   28
# 2                      23   27  420   20
# 3                      25   24   21  412

# %% [markdown]
# ## Model 5: XGB with RandomizedSearchCV

# %%
params = {
    'gamma':[0.1,0.2,0.3,0.4,2,3.5,6,10],
    'learning_rate':[0.01,0.001,0.0001,0.2,0.3,0.4,0.004,00.5,0.7],
    'max_depth':(list(range(1,20))),
    'n_estimators':[50,100,150,200,250,300,350,400,450,500],
    'reg_alpha':[0,0.1,0.2,0.4,0.8,1.6,2.2,4.8,6.4,12.8,16.2,25,50,100],
    'rag_lambda':[0,0.1,0.2,0.4,0.8,1.6,2.2,4.8,6.4,12.8,16.2,25,50,100]
}

xgb2 = XGBClassifier(verbosity=2,random_state=42)
rand = RandomizedSearchCV(param_distributions=params, estimator=xgb2, cv = 3 ,verbose=2 , scoring='accuracy',n_jobs=-1)

rand.fit(X_smote,y_smote)
best_params = rand.best_params_
print(f'Best Paramater:{best_params}')
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Best Paramater:{'reg_alpha': 6.4, 'rag_lambda': 0, 'n_estimators': 100, 'max_depth': 7, 'learning_rate': 0.5, 'gamma': 0.2}

# %%
from xgboost import XGBClassifier
xgb2 = XGBClassifier(n_estimators=250)
xgb2.fit(X_smote,y_smote)
xgb2_pred = xgb2.predict(X_test)

# %%
accuracy_score(y_test,xgb2_pred)
# Out:
# 0.8445

# %%
print(classification_report(y_test,xgb_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.84      0.84       491
#            1       0.85      0.83      0.84       537
#            2       0.83      0.84      0.84       490
#            3       0.84      0.86      0.85       482
#
#     accuracy                           0.84      2000
#    macro avg       0.84      0.84      0.84      2000
# weighted avg       0.84      0.84      0.84      2000

# %% [markdown]
# ## Model 6: Bagging Classifier

# %%
from sklearn.ensemble import BaggingClassifier
bagg = BaggingClassifier(n_estimators=150)
bagg.fit(X_smote,y_smote)
bagg_pred = bagg.predict(X_test)

# %%
accuracy_score(y_test,bagg_pred)
# Out:
# 0.8525

# %%
print(classification_report(y_test,bagg_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.85      0.84       491
#            1       0.88      0.86      0.87       537
#            2       0.85      0.86      0.85       490
#            3       0.85      0.85      0.85       482
#
#     accuracy                           0.85      2000
#    macro avg       0.85      0.85      0.85      2000
# weighted avg       0.85      0.85      0.85      2000

# %%
pd.crosstab(y_test,bagg_pred)
# Out:
# col_0                   0    1    2    3
# Mental_Health_Status
# 0                     415   24   32   20
# 1                      27  461   23   26
# 2                      22   20  420   28
# 3                      31   21   21  409

# %%
from sklearn.ensemble import BaggingClassifier
bagg2 = BaggingClassifier(n_estimators=350)
bagg2.fit(X_smote,y_smote)
bagg2_pred = bagg2.predict(X_test)

# %%
accuracy_score(y_test,bagg2_pred)
# Out:
# 0.8555

# %%
print(classification_report(y_test,bagg2_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.84      0.84       491
#            1       0.87      0.86      0.87       537
#            2       0.84      0.87      0.85       490
#            3       0.85      0.86      0.86       482
#
#     accuracy                           0.86      2000
#    macro avg       0.86      0.86      0.86      2000
# weighted avg       0.86      0.86      0.86      2000

# %% [markdown]
# ## Model Comparison

# %%
df = pd.DataFrame()
df['Model']=['Decision Tree','Random Forest','Random Forest Classifier with RandomizedSearchCV','XGB Boost','XGB with RandomizedSearchCV',
             'Bagging Classifier',]
df['Accuracy'] = [84.6,85.5,85.3,84.2,84.4,85.5]
df
# Out:
#                                               Model  Accuracy
# 0                                     Decision Tree      84.6
# 1                                     Random Forest      85.5
# 2  Random Forest Classifier with RandomizedSearchCV      85.3
# 3                                         XGB Boost      84.2
# 4                       XGB with RandomizedSearchCV      84.4
# 5                                Bagging Classifier      85.5

# %% [markdown]
# ### Coparision using Graph

# %%
plt.figure(figsize=(18,8))
sns.set(style='whitegrid')
sns.barplot(x='Model',y='Accuracy',data=df,palette='bright')
plt.title('Models')
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# ## Model Comparison Summary:
#
# You have compared the performance of several machine learning models based on their accuracy. Here’s a summary of the results:
#
# 1. **Random Forest** and **Bagging Classifier** models achieved the highest accuracy of **85.5%**. These models are ensemble methods, which often perform well in classification tasks by combining the predictions of multiple base models.
#
# 2. **Random Forest Classifier with RandomizedSearchCV** slightly lags behind with an accuracy of **85.3%**. This approach involves hyperparameter tuning, which can sometimes lead to slight variations in accuracy but can also improve model performance if done correctly.
#
# 3. **Decision Tree** is the simplest model among the ones compared, and it achieved an accuracy of **84.6%**. Decision Trees are prone to overfitting, especially without pruning or when not used in an ensemble method like Random Forest.
#
# 4. **XGB Boost** (XGBoost) has an accuracy of **84.2%**. XGBoost is a powerful boosting algorithm known for its high performance, but in this case, it did not outperform the ensemble methods.
#
# 5. **XGB with RandomizedSearchCV** showed a slight improvement over standard XGBoost, achieving **84.4%** accuracy. Like the Random Forest, this model benefits from hyperparameter tuning.
#
# ### Key Takeaways:
# - **Ensemble methods** (Random Forest and Bagging Classifier) are the top performers, suggesting that combining multiple models or trees can lead to better accuracy.
# - **Hyperparameter tuning** (as done with RandomizedSearchCV) can fine-tune models for better performance, though the gains may be incremental.
# - While **Decision Tree** and **XGBoost** are strong contenders, they didn’t outperform the ensemble methods in this particular dataset.
#
# If you’re looking to optimize further, focusing on hyperparameter tuning or exploring other ensemble methods might provide additional gains in accuracy.

# %%
import pickle 
pickle.dump(bagg2,open('model.pkl','wb'))

# %%
data.head()
# Out:
#    Age  Gender  Technology_Usage_Hours  Social_Media_Usage_Hours  \
# 0   23       0                    6.57                      6.00
# 1   21       1                    3.01                      2.57
# 2   51       1                    3.04                      6.14
# 3   25       0                    3.84                      4.48
# 4   53       1                    1.20                      0.56
#
#    Gaming_Hours  Screen_Time_Hours  Mental_Health_Status  Stress_Level  \
# 0          0.68              12.36                     2             1
# 1          3.74               7.61                     0             0
# 2          1.26               3.16                     1             0
# 3          2.59              13.08                     3             2
# 4          0.29              12.63                     2             1
#
#    Sleep_Hours  Physical_Activity_Hours  Support_Systems_Access  \
# 0         8.01                     6.71                       1
# ...

# %%
bagg2.predict(np.array([21,1,6.2,3.4,1.2,12.4,2,6.2,1,1,0,1]).reshape(1,12))
# Out:
# array([3], dtype=int64)

# %% [markdown]
# My Model Perform very Well

# %%
from flask import Flask
